# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import os
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer, SpatialDropout1D, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.math import confusion_matrix

# %% [markdown]
# ## Load data

# %%
def to_3D(input_data):
    print("Before reshaping: ", input_data.shape)
    X = []
    for row in input_data: 
        X.append([row])
    X = np.asarray(X)
    print("After reshaping: ", X.shape)
    return X

# %%
features = np.loadtxt('data/mfcc_mel/features.txt')
targets = np.loadtxt('data/mfcc_mel/targets.txt')
features_3D = to_3D(features)
# Out:
# Before reshaping:  (7442, 145)
# After reshaping:  (7442, 1, 145)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_3D, targets, test_size=0.2, random_state=1)

# %% [markdown]
# ## Model

# %%
def create_model():
    model = Sequential()
    model.add(InputLayer(input_shape=(1, 145)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(SpatialDropout1D(0.1))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.1)))
    model.add(Dense(6, activation='softmax'))
    opt = Adam(learning_rate=0.00001)
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 1, 512)            823296
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 1, 512)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 512)               1574912
# _________________________________________________________________
# dense (Dense)                (None, 6)                 3078
# =================================================================
# Total params: 5,551,110
# Trainable params: 5,551,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(patience=10,restore_best_weights=True)
checkpoint_path = "ckpts/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, verbose=1)
batch_size = 32
epochs = 150

history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
         validation_split=0.15,
         callbacks=[cp_callback])
# Out:
# Epoch 1/150
# 159/159 [==============================] - 27s 81ms/step - loss: 1.7915 - accuracy: 0.1725 - val_loss: 1.7904 - val_accuracy: 0.1736
#
# Epoch 00001: saving model to ckpts/cp.ckpt
# Epoch 2/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.7909 - accuracy: 0.1820 - val_loss: 1.7889 - val_accuracy: 0.1848
#
# Epoch 00002: saving model to ckpts/cp.ckpt
# Epoch 3/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.7900 - accuracy: 0.1898 - val_loss: 1.7868 - val_accuracy: 0.2430
#
# Epoch 00003: saving model to ckpts/cp.ckpt
# Epoch 4/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.7885 - accuracy: 0.2028 - val_loss: 1.7836 - val_accuracy: 0.2172
#
# Epoch 00004: saving model to ckpts/cp.ckpt
# Epoch 5/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.7861 - accuracy: 0.2343 - val_loss: 1.7773 - val_accuracy: 0.2721
#
# Epoch 00005: saving model to ckpts/cp.ckpt
# Epoch 6/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.7812 - accuracy: 0.2491 - val_loss: 1.7637 - val_accuracy: 0.2676
#
# Epoch 00006: saving model to ckpts/cp.ckpt
# Epoch 7/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.7709 - accuracy: 0.2646 - val_loss: 1.7318 - val_accuracy: 0.2889
#
# Epoch 00007: saving model to ckpts/cp.ckpt
# Epoch 8/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.7460 - accuracy: 0.2686 - val_loss: 1.6688 - val_accuracy: 0.2956
#
# Epoch 00008: saving model to ckpts/cp.ckpt
# Epoch 9/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.6939 - accuracy: 0.2886 - val_loss: 1.6155 - val_accuracy: 0.2934
#
# Epoch 00009: saving model to ckpts/cp.ckpt
# Epoch 10/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.6367 - accuracy: 0.2959 - val_loss: 1.6151 - val_accuracy: 0.2945
#
# Epoch 00010: saving model to ckpts/cp.ckpt
# Epoch 11/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.6136 - accuracy: 0.3079 - val_loss: 1.6097 - val_accuracy: 0.3035
#
# Epoch 00011: saving model to ckpts/cp.ckpt
# Epoch 12/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5907 - accuracy: 0.3279 - val_loss: 1.6000 - val_accuracy: 0.3035
#
# Epoch 00012: saving model to ckpts/cp.ckpt
# Epoch 13/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5995 - accuracy: 0.3211 - val_loss: 1.5907 - val_accuracy: 0.3102
#
# Epoch 00013: saving model to ckpts/cp.ckpt
# Epoch 14/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5809 - accuracy: 0.3357 - val_loss: 1.5841 - val_accuracy: 0.3147
#
# Epoch 00014: saving model to ckpts/cp.ckpt
# Epoch 15/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5853 - accuracy: 0.3204 - val_loss: 1.5835 - val_accuracy: 0.3180
#
# Epoch 00015: saving model to ckpts/cp.ckpt
# Epoch 16/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5564 - accuracy: 0.3386 - val_loss: 1.5796 - val_accuracy: 0.3236
#
# Epoch 00016: saving model to ckpts/cp.ckpt
# Epoch 17/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5729 - accuracy: 0.3352 - val_loss: 1.5774 - val_accuracy: 0.3203
#
# Epoch 00017: saving model to ckpts/cp.ckpt
# Epoch 18/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5756 - accuracy: 0.3231 - val_loss: 1.5756 - val_accuracy: 0.3135
#
# Epoch 00018: saving model to ckpts/cp.ckpt
# Epoch 19/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5664 - accuracy: 0.3350 - val_loss: 1.5676 - val_accuracy: 0.3203
#
# Epoch 00019: saving model to ckpts/cp.ckpt
# Epoch 20/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.5713 - accuracy: 0.3255 - val_loss: 1.5657 - val_accuracy: 0.3169
#
# Epoch 00020: saving model to ckpts/cp.ckpt
# Epoch 21/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5433 - accuracy: 0.3416 - val_loss: 1.5613 - val_accuracy: 0.3225
#
# Epoch 00021: saving model to ckpts/cp.ckpt
# Epoch 22/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.5383 - accuracy: 0.3553 - val_loss: 1.5620 - val_accuracy: 0.3203
#
# Epoch 00022: saving model to ckpts/cp.ckpt
# Epoch 23/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5324 - accuracy: 0.3530 - val_loss: 1.5588 - val_accuracy: 0.3113
#
# Epoch 00023: saving model to ckpts/cp.ckpt
# Epoch 24/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5403 - accuracy: 0.3424 - val_loss: 1.5558 - val_accuracy: 0.3203
#
# Epoch 00024: saving model to ckpts/cp.ckpt
# Epoch 25/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5397 - accuracy: 0.3525 - val_loss: 1.5506 - val_accuracy: 0.3113
#
# Epoch 00025: saving model to ckpts/cp.ckpt
# Epoch 26/150
# 159/159 [==============================] - 13s 82ms/step - loss: 1.5402 - accuracy: 0.3536 - val_loss: 1.5534 - val_accuracy: 0.3158
#
# Epoch 00026: saving model to ckpts/cp.ckpt
# Epoch 27/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5206 - accuracy: 0.3647 - val_loss: 1.5541 - val_accuracy: 0.3191
#
# Epoch 00027: saving model to ckpts/cp.ckpt
# Epoch 28/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5393 - accuracy: 0.3370 - val_loss: 1.5504 - val_accuracy: 0.3281
#
# Epoch 00028: saving model to ckpts/cp.ckpt
# Epoch 29/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5244 - accuracy: 0.3590 - val_loss: 1.5499 - val_accuracy: 0.3348
#
# Epoch 00029: saving model to ckpts/cp.ckpt
# Epoch 30/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5330 - accuracy: 0.3492 - val_loss: 1.5449 - val_accuracy: 0.3180
#
# Epoch 00030: saving model to ckpts/cp.ckpt
# Epoch 31/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.5356 - accuracy: 0.3496 - val_loss: 1.5519 - val_accuracy: 0.3326
#
# Epoch 00031: saving model to ckpts/cp.ckpt
# Epoch 32/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5329 - accuracy: 0.3515 - val_loss: 1.5459 - val_accuracy: 0.3315
#
# Epoch 00032: saving model to ckpts/cp.ckpt
# Epoch 33/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5185 - accuracy: 0.3659 - val_loss: 1.5436 - val_accuracy: 0.3315
#
# Epoch 00033: saving model to ckpts/cp.ckpt
# Epoch 34/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5321 - accuracy: 0.3486 - val_loss: 1.5445 - val_accuracy: 0.3371
#
# Epoch 00034: saving model to ckpts/cp.ckpt
# Epoch 35/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5285 - accuracy: 0.3557 - val_loss: 1.5417 - val_accuracy: 0.3303
#
# Epoch 00035: saving model to ckpts/cp.ckpt
# Epoch 36/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.5190 - accuracy: 0.3690 - val_loss: 1.5407 - val_accuracy: 0.3326
#
# Epoch 00036: saving model to ckpts/cp.ckpt
# Epoch 37/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.5077 - accuracy: 0.3708 - val_loss: 1.5410 - val_accuracy: 0.3348
#
# Epoch 00037: saving model to ckpts/cp.ckpt
# Epoch 38/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.5364 - accuracy: 0.3579 - val_loss: 1.5370 - val_accuracy: 0.3359
#
# Epoch 00038: saving model to ckpts/cp.ckpt
# Epoch 39/150
# 159/159 [==============================] - 12s 77ms/step - loss: 1.5280 - accuracy: 0.3560 - val_loss: 1.5410 - val_accuracy: 0.3371
#
# Epoch 00039: saving model to ckpts/cp.ckpt
# Epoch 40/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.5238 - accuracy: 0.3511 - val_loss: 1.5407 - val_accuracy: 0.3337
#
# Epoch 00040: saving model to ckpts/cp.ckpt
# Epoch 41/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.5168 - accuracy: 0.3476 - val_loss: 1.5360 - val_accuracy: 0.3326
#
# Epoch 00041: saving model to ckpts/cp.ckpt
# Epoch 42/150
# 159/159 [==============================] - 14s 86ms/step - loss: 1.5179 - accuracy: 0.3642 - val_loss: 1.5329 - val_accuracy: 0.3292
#
# Epoch 00042: saving model to ckpts/cp.ckpt
# Epoch 43/150
# 159/159 [==============================] - 13s 83ms/step - loss: 1.5095 - accuracy: 0.3563 - val_loss: 1.5323 - val_accuracy: 0.3326
#
# Epoch 00043: saving model to ckpts/cp.ckpt
# Epoch 44/150
# 159/159 [==============================] - 10s 62ms/step - loss: 1.5119 - accuracy: 0.3646 - val_loss: 1.5356 - val_accuracy: 0.3326
#
# Epoch 00044: saving model to ckpts/cp.ckpt
# Epoch 45/150
# 159/159 [==============================] - 10s 66ms/step - loss: 1.5033 - accuracy: 0.3658 - val_loss: 1.5325 - val_accuracy: 0.3371
#
# Epoch 00045: saving model to ckpts/cp.ckpt
# Epoch 46/150
# 159/159 [==============================] - 13s 84ms/step - loss: 1.5212 - accuracy: 0.3569 - val_loss: 1.5317 - val_accuracy: 0.3326
#
# Epoch 00046: saving model to ckpts/cp.ckpt
# Epoch 47/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5141 - accuracy: 0.3593 - val_loss: 1.5299 - val_accuracy: 0.3359
#
# Epoch 00047: saving model to ckpts/cp.ckpt
# Epoch 48/150
# 159/159 [==============================] - 13s 83ms/step - loss: 1.5180 - accuracy: 0.3558 - val_loss: 1.5327 - val_accuracy: 0.3315
#
# Epoch 00048: saving model to ckpts/cp.ckpt
# Epoch 49/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.5031 - accuracy: 0.3664 - val_loss: 1.5324 - val_accuracy: 0.3348
#
# Epoch 00049: saving model to ckpts/cp.ckpt
# Epoch 50/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.5088 - accuracy: 0.3620 - val_loss: 1.5316 - val_accuracy: 0.3359
#
# Epoch 00050: saving model to ckpts/cp.ckpt
# Epoch 51/150
# 159/159 [==============================] - 9s 60ms/step - loss: 1.5000 - accuracy: 0.3706 - val_loss: 1.5315 - val_accuracy: 0.3348
#
# Epoch 00051: saving model to ckpts/cp.ckpt
# Epoch 52/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5037 - accuracy: 0.3653 - val_loss: 1.5303 - val_accuracy: 0.3393
#
# Epoch 00052: saving model to ckpts/cp.ckpt
# Epoch 53/150
# 159/159 [==============================] - 10s 62ms/step - loss: 1.5025 - accuracy: 0.3659 - val_loss: 1.5303 - val_accuracy: 0.3359
#
# Epoch 00053: saving model to ckpts/cp.ckpt
# Epoch 54/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5140 - accuracy: 0.3550 - val_loss: 1.5298 - val_accuracy: 0.3382
#
# Epoch 00054: saving model to ckpts/cp.ckpt
# Epoch 55/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5074 - accuracy: 0.3490 - val_loss: 1.5298 - val_accuracy: 0.3404
#
# Epoch 00055: saving model to ckpts/cp.ckpt
# Epoch 56/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5051 - accuracy: 0.3566 - val_loss: 1.5295 - val_accuracy: 0.3438
#
# Epoch 00056: saving model to ckpts/cp.ckpt
# Epoch 57/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5136 - accuracy: 0.3667 - val_loss: 1.5256 - val_accuracy: 0.3404
#
# Epoch 00057: saving model to ckpts/cp.ckpt
# Epoch 58/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5055 - accuracy: 0.3618 - val_loss: 1.5265 - val_accuracy: 0.3404
#
# Epoch 00058: saving model to ckpts/cp.ckpt
# Epoch 59/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5143 - accuracy: 0.3713 - val_loss: 1.5280 - val_accuracy: 0.3427
#
# Epoch 00059: saving model to ckpts/cp.ckpt
# Epoch 60/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4989 - accuracy: 0.3708 - val_loss: 1.5251 - val_accuracy: 0.3404
#
# Epoch 00060: saving model to ckpts/cp.ckpt
# Epoch 61/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4895 - accuracy: 0.3804 - val_loss: 1.5249 - val_accuracy: 0.3427
#
# Epoch 00061: saving model to ckpts/cp.ckpt
# Epoch 62/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5161 - accuracy: 0.3578 - val_loss: 1.5255 - val_accuracy: 0.3460
#
# Epoch 00062: saving model to ckpts/cp.ckpt
# Epoch 63/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.4981 - accuracy: 0.3664 - val_loss: 1.5260 - val_accuracy: 0.3460
#
# Epoch 00063: saving model to ckpts/cp.ckpt
# Epoch 64/150
# 159/159 [==============================] - 12s 77ms/step - loss: 1.5104 - accuracy: 0.3622 - val_loss: 1.5225 - val_accuracy: 0.3449
#
# Epoch 00064: saving model to ckpts/cp.ckpt
# Epoch 65/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.5025 - accuracy: 0.3570 - val_loss: 1.5247 - val_accuracy: 0.3460
#
# Epoch 00065: saving model to ckpts/cp.ckpt
# Epoch 66/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5054 - accuracy: 0.3583 - val_loss: 1.5231 - val_accuracy: 0.3483
#
# Epoch 00066: saving model to ckpts/cp.ckpt
# Epoch 67/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5163 - accuracy: 0.3560 - val_loss: 1.5237 - val_accuracy: 0.3494
#
# Epoch 00067: saving model to ckpts/cp.ckpt
# Epoch 68/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.5046 - accuracy: 0.3743 - val_loss: 1.5228 - val_accuracy: 0.3483
#
# Epoch 00068: saving model to ckpts/cp.ckpt
# Epoch 69/150
# 159/159 [==============================] - 10s 65ms/step - loss: 1.5106 - accuracy: 0.3561 - val_loss: 1.5235 - val_accuracy: 0.3494
#
# Epoch 00069: saving model to ckpts/cp.ckpt
# Epoch 70/150
# 159/159 [==============================] - 10s 65ms/step - loss: 1.5083 - accuracy: 0.3652 - val_loss: 1.5205 - val_accuracy: 0.3527
#
# Epoch 00070: saving model to ckpts/cp.ckpt
# Epoch 71/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.4950 - accuracy: 0.3811 - val_loss: 1.5194 - val_accuracy: 0.3471
#
# Epoch 00071: saving model to ckpts/cp.ckpt
# Epoch 72/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4920 - accuracy: 0.3772 - val_loss: 1.5188 - val_accuracy: 0.3449
#
# Epoch 00072: saving model to ckpts/cp.ckpt
# Epoch 73/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4789 - accuracy: 0.3711 - val_loss: 1.5205 - val_accuracy: 0.3527
#
# Epoch 00073: saving model to ckpts/cp.ckpt
# Epoch 74/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4983 - accuracy: 0.3702 - val_loss: 1.5181 - val_accuracy: 0.3460
#
# Epoch 00074: saving model to ckpts/cp.ckpt
# Epoch 75/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.5098 - accuracy: 0.3605 - val_loss: 1.5199 - val_accuracy: 0.3427
#
# Epoch 00075: saving model to ckpts/cp.ckpt
# Epoch 76/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4952 - accuracy: 0.3696 - val_loss: 1.5160 - val_accuracy: 0.3494
#
# Epoch 00076: saving model to ckpts/cp.ckpt
# Epoch 77/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.5089 - accuracy: 0.3597 - val_loss: 1.5172 - val_accuracy: 0.3471
#
# Epoch 00077: saving model to ckpts/cp.ckpt
# Epoch 78/150
# 159/159 [==============================] - 13s 80ms/step - loss: 1.5152 - accuracy: 0.3573 - val_loss: 1.5180 - val_accuracy: 0.3494
#
# Epoch 00078: saving model to ckpts/cp.ckpt
# Epoch 79/150
# 159/159 [==============================] - 13s 80ms/step - loss: 1.4885 - accuracy: 0.3649 - val_loss: 1.5171 - val_accuracy: 0.3471
#
# Epoch 00079: saving model to ckpts/cp.ckpt
# Epoch 80/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4958 - accuracy: 0.3657 - val_loss: 1.5169 - val_accuracy: 0.3471
#
# Epoch 00080: saving model to ckpts/cp.ckpt
# Epoch 81/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4888 - accuracy: 0.3672 - val_loss: 1.5183 - val_accuracy: 0.3494
#
# Epoch 00081: saving model to ckpts/cp.ckpt
# Epoch 82/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4953 - accuracy: 0.3674 - val_loss: 1.5190 - val_accuracy: 0.3471
#
# Epoch 00082: saving model to ckpts/cp.ckpt
# Epoch 83/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4822 - accuracy: 0.3701 - val_loss: 1.5150 - val_accuracy: 0.3471
#
# Epoch 00083: saving model to ckpts/cp.ckpt
# Epoch 84/150
# 159/159 [==============================] - 10s 61ms/step - loss: 1.4849 - accuracy: 0.3804 - val_loss: 1.5187 - val_accuracy: 0.3483
#
# Epoch 00084: saving model to ckpts/cp.ckpt
# Epoch 85/150
# 159/159 [==============================] - 10s 65ms/step - loss: 1.4872 - accuracy: 0.3705 - val_loss: 1.5145 - val_accuracy: 0.3483
#
# Epoch 00085: saving model to ckpts/cp.ckpt
# Epoch 86/150
# 159/159 [==============================] - 10s 63ms/step - loss: 1.4846 - accuracy: 0.3659 - val_loss: 1.5144 - val_accuracy: 0.3483
#
# Epoch 00086: saving model to ckpts/cp.ckpt
# Epoch 87/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4855 - accuracy: 0.3637 - val_loss: 1.5149 - val_accuracy: 0.3516
#
# Epoch 00087: saving model to ckpts/cp.ckpt
# Epoch 88/150
# 159/159 [==============================] - 10s 65ms/step - loss: 1.4854 - accuracy: 0.3708 - val_loss: 1.5168 - val_accuracy: 0.3516
#
# Epoch 00088: saving model to ckpts/cp.ckpt
# Epoch 89/150
# 159/159 [==============================] - 10s 62ms/step - loss: 1.4924 - accuracy: 0.3650 - val_loss: 1.5153 - val_accuracy: 0.3516
#
# Epoch 00089: saving model to ckpts/cp.ckpt
# Epoch 90/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4877 - accuracy: 0.3673 - val_loss: 1.5157 - val_accuracy: 0.3460
#
# Epoch 00090: saving model to ckpts/cp.ckpt
# Epoch 91/150
# 159/159 [==============================] - 13s 80ms/step - loss: 1.4853 - accuracy: 0.3631 - val_loss: 1.5150 - val_accuracy: 0.3527
#
# Epoch 00091: saving model to ckpts/cp.ckpt
# Epoch 92/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4769 - accuracy: 0.3788 - val_loss: 1.5148 - val_accuracy: 0.3471
#
# Epoch 00092: saving model to ckpts/cp.ckpt
# Epoch 93/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4658 - accuracy: 0.3800 - val_loss: 1.5135 - val_accuracy: 0.3539
#
# Epoch 00093: saving model to ckpts/cp.ckpt
# Epoch 94/150
# 159/159 [==============================] - 11s 67ms/step - loss: 1.4701 - accuracy: 0.3777 - val_loss: 1.5158 - val_accuracy: 0.3550
#
# Epoch 00094: saving model to ckpts/cp.ckpt
# Epoch 95/150
# 159/159 [==============================] - 10s 62ms/step - loss: 1.4862 - accuracy: 0.3688 - val_loss: 1.5155 - val_accuracy: 0.3561
#
# Epoch 00095: saving model to ckpts/cp.ckpt
# Epoch 96/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4518 - accuracy: 0.3906 - val_loss: 1.5122 - val_accuracy: 0.3539
#
# Epoch 00096: saving model to ckpts/cp.ckpt
# Epoch 97/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4848 - accuracy: 0.3718 - val_loss: 1.5119 - val_accuracy: 0.3527
#
# Epoch 00097: saving model to ckpts/cp.ckpt
# Epoch 98/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.4886 - accuracy: 0.3765 - val_loss: 1.5140 - val_accuracy: 0.3550
#
# Epoch 00098: saving model to ckpts/cp.ckpt
# Epoch 99/150
# 159/159 [==============================] - 10s 66ms/step - loss: 1.4754 - accuracy: 0.3703 - val_loss: 1.5105 - val_accuracy: 0.3527
#
# Epoch 00099: saving model to ckpts/cp.ckpt
# Epoch 100/150
# 159/159 [==============================] - 10s 64ms/step - loss: 1.4972 - accuracy: 0.3638 - val_loss: 1.5140 - val_accuracy: 0.3572
#
# Epoch 00100: saving model to ckpts/cp.ckpt
# Epoch 101/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4696 - accuracy: 0.3776 - val_loss: 1.5110 - val_accuracy: 0.3516
#
# Epoch 00101: saving model to ckpts/cp.ckpt
# Epoch 102/150
# 159/159 [==============================] - 11s 67ms/step - loss: 1.4839 - accuracy: 0.3645 - val_loss: 1.5111 - val_accuracy: 0.3572
#
# Epoch 00102: saving model to ckpts/cp.ckpt
# Epoch 103/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4720 - accuracy: 0.3778 - val_loss: 1.5110 - val_accuracy: 0.3550
#
# Epoch 00103: saving model to ckpts/cp.ckpt
# Epoch 104/150
# 159/159 [==============================] - 10s 66ms/step - loss: 1.4728 - accuracy: 0.3714 - val_loss: 1.5099 - val_accuracy: 0.3561
#
# Epoch 00104: saving model to ckpts/cp.ckpt
# Epoch 105/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4913 - accuracy: 0.3818 - val_loss: 1.5107 - val_accuracy: 0.3561
#
# Epoch 00105: saving model to ckpts/cp.ckpt
# Epoch 106/150
# 159/159 [==============================] - 13s 84ms/step - loss: 1.4822 - accuracy: 0.3774 - val_loss: 1.5101 - val_accuracy: 0.3561
#
# Epoch 00106: saving model to ckpts/cp.ckpt
# Epoch 107/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.4762 - accuracy: 0.3779 - val_loss: 1.5097 - val_accuracy: 0.3550
#
# Epoch 00107: saving model to ckpts/cp.ckpt
# Epoch 108/150
# 159/159 [==============================] - 13s 82ms/step - loss: 1.4842 - accuracy: 0.3713 - val_loss: 1.5095 - val_accuracy: 0.3583
#
# Epoch 00108: saving model to ckpts/cp.ckpt
# Epoch 109/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4850 - accuracy: 0.3688 - val_loss: 1.5094 - val_accuracy: 0.3606
#
# Epoch 00109: saving model to ckpts/cp.ckpt
# Epoch 110/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.4621 - accuracy: 0.3863 - val_loss: 1.5061 - val_accuracy: 0.3505
#
# Epoch 00110: saving model to ckpts/cp.ckpt
# Epoch 111/150
# 159/159 [==============================] - 12s 77ms/step - loss: 1.4761 - accuracy: 0.3708 - val_loss: 1.5092 - val_accuracy: 0.3561
#
# Epoch 00111: saving model to ckpts/cp.ckpt
# Epoch 112/150
# 159/159 [==============================] - 13s 79ms/step - loss: 1.4530 - accuracy: 0.3863 - val_loss: 1.5093 - val_accuracy: 0.3572
#
# Epoch 00112: saving model to ckpts/cp.ckpt
# Epoch 113/150
# 159/159 [==============================] - 15s 91ms/step - loss: 1.4773 - accuracy: 0.3805 - val_loss: 1.5068 - val_accuracy: 0.3527
#
# Epoch 00113: saving model to ckpts/cp.ckpt
# Epoch 114/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.4806 - accuracy: 0.3694 - val_loss: 1.5080 - val_accuracy: 0.3606
#
# Epoch 00114: saving model to ckpts/cp.ckpt
# Epoch 115/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4717 - accuracy: 0.3831 - val_loss: 1.5070 - val_accuracy: 0.3583
#
# Epoch 00115: saving model to ckpts/cp.ckpt
# Epoch 116/150
# 159/159 [==============================] - 11s 67ms/step - loss: 1.4772 - accuracy: 0.3699 - val_loss: 1.5080 - val_accuracy: 0.3561
#
# Epoch 00116: saving model to ckpts/cp.ckpt
# Epoch 117/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4899 - accuracy: 0.3704 - val_loss: 1.5043 - val_accuracy: 0.3539
#
# Epoch 00117: saving model to ckpts/cp.ckpt
# Epoch 118/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4750 - accuracy: 0.3791 - val_loss: 1.5089 - val_accuracy: 0.3572
#
# Epoch 00118: saving model to ckpts/cp.ckpt
# Epoch 119/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4742 - accuracy: 0.3784 - val_loss: 1.5062 - val_accuracy: 0.3572
#
# Epoch 00119: saving model to ckpts/cp.ckpt
# Epoch 120/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4557 - accuracy: 0.3867 - val_loss: 1.5050 - val_accuracy: 0.3583
#
# Epoch 00120: saving model to ckpts/cp.ckpt
# Epoch 121/150
# 159/159 [==============================] - 13s 85ms/step - loss: 1.4813 - accuracy: 0.3784 - val_loss: 1.5043 - val_accuracy: 0.3561
#
# Epoch 00121: saving model to ckpts/cp.ckpt
# Epoch 122/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.4734 - accuracy: 0.3714 - val_loss: 1.5048 - val_accuracy: 0.3572
#
# Epoch 00122: saving model to ckpts/cp.ckpt
# Epoch 123/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4849 - accuracy: 0.3822 - val_loss: 1.5080 - val_accuracy: 0.3550
#
# Epoch 00123: saving model to ckpts/cp.ckpt
# Epoch 124/150
# 159/159 [==============================] - 14s 88ms/step - loss: 1.4751 - accuracy: 0.3691 - val_loss: 1.5047 - val_accuracy: 0.3561
#
# Epoch 00124: saving model to ckpts/cp.ckpt
# Epoch 125/150
# 159/159 [==============================] - 11s 66ms/step - loss: 1.4602 - accuracy: 0.3881 - val_loss: 1.5062 - val_accuracy: 0.3561
#
# Epoch 00125: saving model to ckpts/cp.ckpt
# Epoch 126/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4702 - accuracy: 0.3773 - val_loss: 1.5049 - val_accuracy: 0.3583
#
# Epoch 00126: saving model to ckpts/cp.ckpt
# Epoch 127/150
# 159/159 [==============================] - 11s 67ms/step - loss: 1.4657 - accuracy: 0.3903 - val_loss: 1.5038 - val_accuracy: 0.3561
#
# Epoch 00127: saving model to ckpts/cp.ckpt
# Epoch 128/150
# 159/159 [==============================] - 11s 66ms/step - loss: 1.4726 - accuracy: 0.3669 - val_loss: 1.5008 - val_accuracy: 0.3550
#
# Epoch 00128: saving model to ckpts/cp.ckpt
# Epoch 129/150
# 159/159 [==============================] - 11s 66ms/step - loss: 1.4848 - accuracy: 0.3737 - val_loss: 1.5033 - val_accuracy: 0.3539
#
# Epoch 00129: saving model to ckpts/cp.ckpt
# Epoch 130/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4761 - accuracy: 0.3807 - val_loss: 1.5056 - val_accuracy: 0.3572
#
# Epoch 00130: saving model to ckpts/cp.ckpt
# Epoch 131/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4552 - accuracy: 0.3812 - val_loss: 1.5057 - val_accuracy: 0.3572
#
# Epoch 00131: saving model to ckpts/cp.ckpt
# Epoch 132/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4694 - accuracy: 0.3842 - val_loss: 1.5020 - val_accuracy: 0.3595
#
# Epoch 00132: saving model to ckpts/cp.ckpt
# Epoch 133/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4678 - accuracy: 0.3746 - val_loss: 1.5012 - val_accuracy: 0.3572
#
# Epoch 00133: saving model to ckpts/cp.ckpt
# Epoch 134/150
# 159/159 [==============================] - 14s 88ms/step - loss: 1.4596 - accuracy: 0.3920 - val_loss: 1.4989 - val_accuracy: 0.3561
#
# Epoch 00134: saving model to ckpts/cp.ckpt
# Epoch 135/150
# 159/159 [==============================] - 13s 84ms/step - loss: 1.4928 - accuracy: 0.3766 - val_loss: 1.5060 - val_accuracy: 0.3550
#
# Epoch 00135: saving model to ckpts/cp.ckpt
# Epoch 136/150
# 159/159 [==============================] - 14s 86ms/step - loss: 1.4731 - accuracy: 0.3781 - val_loss: 1.5018 - val_accuracy: 0.3583
#
# Epoch 00136: saving model to ckpts/cp.ckpt
# Epoch 137/150
# 159/159 [==============================] - 14s 90ms/step - loss: 1.4641 - accuracy: 0.3835 - val_loss: 1.5001 - val_accuracy: 0.3583
#
# Epoch 00137: saving model to ckpts/cp.ckpt
# Epoch 138/150
# 159/159 [==============================] - 13s 80ms/step - loss: 1.4668 - accuracy: 0.3686 - val_loss: 1.5014 - val_accuracy: 0.3561
#
# Epoch 00138: saving model to ckpts/cp.ckpt
# Epoch 139/150
# 159/159 [==============================] - 13s 79ms/step - loss: 1.4589 - accuracy: 0.3895 - val_loss: 1.5000 - val_accuracy: 0.3595
#
# Epoch 00139: saving model to ckpts/cp.ckpt
# Epoch 140/150
# 159/159 [==============================] - 12s 79ms/step - loss: 1.4548 - accuracy: 0.3885 - val_loss: 1.5021 - val_accuracy: 0.3561
#
# Epoch 00140: saving model to ckpts/cp.ckpt
# Epoch 141/150
# 159/159 [==============================] - 13s 80ms/step - loss: 1.4578 - accuracy: 0.3780 - val_loss: 1.4985 - val_accuracy: 0.3572
#
# Epoch 00141: saving model to ckpts/cp.ckpt
# Epoch 142/150
# 159/159 [==============================] - 17s 110ms/step - loss: 1.4518 - accuracy: 0.3886 - val_loss: 1.5004 - val_accuracy: 0.3572
#
# Epoch 00142: saving model to ckpts/cp.ckpt
# Epoch 143/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4511 - accuracy: 0.4000 - val_loss: 1.4982 - val_accuracy: 0.3606
#
# Epoch 00143: saving model to ckpts/cp.ckpt
# Epoch 144/150
# 159/159 [==============================] - 14s 89ms/step - loss: 1.4674 - accuracy: 0.3889 - val_loss: 1.4988 - val_accuracy: 0.3606
#
# Epoch 00144: saving model to ckpts/cp.ckpt
# Epoch 145/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4698 - accuracy: 0.3857 - val_loss: 1.4979 - val_accuracy: 0.3583
#
# Epoch 00145: saving model to ckpts/cp.ckpt
# Epoch 146/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4570 - accuracy: 0.3983 - val_loss: 1.4966 - val_accuracy: 0.3651
#
# Epoch 00146: saving model to ckpts/cp.ckpt
# Epoch 147/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.4564 - accuracy: 0.3832 - val_loss: 1.4961 - val_accuracy: 0.3606
#
# Epoch 00147: saving model to ckpts/cp.ckpt
# Epoch 148/150
# 159/159 [==============================] - 12s 78ms/step - loss: 1.4690 - accuracy: 0.3936 - val_loss: 1.4984 - val_accuracy: 0.3617
#
# Epoch 00148: saving model to ckpts/cp.ckpt
# Epoch 149/150
# 159/159 [==============================] - 13s 82ms/step - loss: 1.4667 - accuracy: 0.3793 - val_loss: 1.4954 - val_accuracy: 0.3583
#
# Epoch 00149: saving model to ckpts/cp.ckpt
# Epoch 150/150
# 159/159 [==============================] - 14s 90ms/step - loss: 1.4631 - accuracy: 0.3768 - val_loss: 1.4993 - val_accuracy: 0.3583
#
# Epoch 00150: saving model to ckpts/cp.ckpt

# %% [markdown]
# ## Metrics

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
accuracy = model.evaluate(X_test, y_test)
print('Loss: {:0.3f}\nAccuracy: {:0.3f}'.format(accuracy[0],accuracy[1]))
# Out:
# 47/47 [==============================] - 1s 12ms/step - loss: 1.4196 - accuracy: 0.4359
# Loss: 1.420
# Accuracy: 0.436

# %%
prediction = model.predict_classes(X_test)
label = np.where(y_test)[1]
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
confusion = confusion_matrix(labels=label, predictions=prediction, num_classes=6)

# %%
cate = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad']

# %%
cm = pd.DataFrame(confusion.numpy(), index = [i for i in cate] , columns = [i for i in cate])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
