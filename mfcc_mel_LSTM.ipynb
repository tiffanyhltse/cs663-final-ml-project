# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import os
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer, SpatialDropout1D, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.math import confusion_matrix

# %% [markdown]
# ## Load data

# %%
def to_3D(input_data):
    print("Before reshaping: ", input_data.shape)
    X = []
    for row in input_data: 
        X.append([row])
    X = np.asarray(X)
    print("After reshaping: ", X.shape)
    return X

# %%
features = np.loadtxt('mfcc_mel/features.txt')
targets = np.loadtxt('mfcc_mel/targets.txt')
features_3D = to_3D(features)
# Out:
# Before reshaping:  (7442, 145)
# After reshaping:  (7442, 1, 145)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_3D, targets, test_size=0.2, random_state=1)

# %% [markdown]
# ## Model

# %%
def create_model():
    model = Sequential()
    model.add(InputLayer(input_shape=(1, 145)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(SpatialDropout1D(0.1))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.2, return_sequences = True)))
    model.add(Bidirectional(LSTM(256, dropout=0.2, recurrent_dropout=0.1)))
    model.add(Dense(6, activation='softmax'))
    opt = Adam(learning_rate=0.00001)
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 1, 512)            823296
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 1, 512)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 1, 512)            1574912
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 512)               1574912
# _________________________________________________________________
# dense (Dense)                (None, 6)                 3078
# =================================================================
# Total params: 5,551,110
# Trainable params: 5,551,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(patience=10,restore_best_weights=True)
checkpoint_path = "ckpts/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, verbose=1)
batch_size = 32
epochs = 150

history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
         validation_split=0.15,
         callbacks=[cp_callback])
# Out:
# Epoch 1/150
# 159/159 [==============================] - 29s 85ms/step - loss: 1.7918 - accuracy: 0.1540 - val_loss: 1.7907 - val_accuracy: 0.1848
#
# Epoch 00001: saving model to ckpts/cp.ckpt
# Epoch 2/150
# 159/159 [==============================] - 11s 67ms/step - loss: 1.7910 - accuracy: 0.1885 - val_loss: 1.7895 - val_accuracy: 0.2004
#
# Epoch 00002: saving model to ckpts/cp.ckpt
# Epoch 3/150
# 159/159 [==============================] - 11s 66ms/step - loss: 1.7899 - accuracy: 0.2050 - val_loss: 1.7877 - val_accuracy: 0.2150
#
# Epoch 00003: saving model to ckpts/cp.ckpt
# Epoch 4/150
# 159/159 [==============================] - 10s 66ms/step - loss: 1.7886 - accuracy: 0.2164 - val_loss: 1.7848 - val_accuracy: 0.2284
#
# Epoch 00004: saving model to ckpts/cp.ckpt
# Epoch 5/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.7865 - accuracy: 0.2395 - val_loss: 1.7792 - val_accuracy: 0.2878
#
# Epoch 00005: saving model to ckpts/cp.ckpt
# Epoch 6/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.7820 - accuracy: 0.2641 - val_loss: 1.7674 - val_accuracy: 0.3046
#
# Epoch 00006: saving model to ckpts/cp.ckpt
# Epoch 7/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.7723 - accuracy: 0.2846 - val_loss: 1.7366 - val_accuracy: 0.2956
#
# Epoch 00007: saving model to ckpts/cp.ckpt
# Epoch 8/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.7441 - accuracy: 0.2923 - val_loss: 1.6679 - val_accuracy: 0.3001
#
# Epoch 00008: saving model to ckpts/cp.ckpt
# Epoch 9/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.6887 - accuracy: 0.2977 - val_loss: 1.6081 - val_accuracy: 0.2934
#
# Epoch 00009: saving model to ckpts/cp.ckpt
# Epoch 10/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.6339 - accuracy: 0.3043 - val_loss: 1.6072 - val_accuracy: 0.3035
#
# Epoch 00010: saving model to ckpts/cp.ckpt
# Epoch 11/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.6010 - accuracy: 0.3180 - val_loss: 1.6003 - val_accuracy: 0.3035
#
# Epoch 00011: saving model to ckpts/cp.ckpt
# Epoch 12/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5947 - accuracy: 0.3269 - val_loss: 1.5887 - val_accuracy: 0.3091
#
# Epoch 00012: saving model to ckpts/cp.ckpt
# Epoch 13/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5835 - accuracy: 0.3236 - val_loss: 1.5841 - val_accuracy: 0.3124
#
# Epoch 00013: saving model to ckpts/cp.ckpt
# Epoch 14/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5772 - accuracy: 0.3196 - val_loss: 1.5815 - val_accuracy: 0.3113
#
# Epoch 00014: saving model to ckpts/cp.ckpt
# Epoch 15/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5791 - accuracy: 0.3278 - val_loss: 1.5754 - val_accuracy: 0.3102
#
# Epoch 00015: saving model to ckpts/cp.ckpt
# Epoch 16/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.5661 - accuracy: 0.3327 - val_loss: 1.5744 - val_accuracy: 0.3124
#
# Epoch 00016: saving model to ckpts/cp.ckpt
# Epoch 17/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5648 - accuracy: 0.3318 - val_loss: 1.5701 - val_accuracy: 0.3091
#
# Epoch 00017: saving model to ckpts/cp.ckpt
# Epoch 18/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5766 - accuracy: 0.3327 - val_loss: 1.5675 - val_accuracy: 0.3113
#
# Epoch 00018: saving model to ckpts/cp.ckpt
# Epoch 19/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5469 - accuracy: 0.3450 - val_loss: 1.5635 - val_accuracy: 0.3113
#
# Epoch 00019: saving model to ckpts/cp.ckpt
# Epoch 20/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5556 - accuracy: 0.3369 - val_loss: 1.5627 - val_accuracy: 0.3113
#
# Epoch 00020: saving model to ckpts/cp.ckpt
# Epoch 21/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5462 - accuracy: 0.3326 - val_loss: 1.5611 - val_accuracy: 0.3169
#
# Epoch 00021: saving model to ckpts/cp.ckpt
# Epoch 22/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5498 - accuracy: 0.3330 - val_loss: 1.5581 - val_accuracy: 0.3180
#
# Epoch 00022: saving model to ckpts/cp.ckpt
# Epoch 23/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5511 - accuracy: 0.3490 - val_loss: 1.5556 - val_accuracy: 0.3169
#
# Epoch 00023: saving model to ckpts/cp.ckpt
# Epoch 24/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5382 - accuracy: 0.3509 - val_loss: 1.5519 - val_accuracy: 0.3158
#
# Epoch 00024: saving model to ckpts/cp.ckpt
# Epoch 25/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5180 - accuracy: 0.3446 - val_loss: 1.5475 - val_accuracy: 0.3191
#
# Epoch 00025: saving model to ckpts/cp.ckpt
# Epoch 26/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.5354 - accuracy: 0.3510 - val_loss: 1.5502 - val_accuracy: 0.3191
#
# Epoch 00026: saving model to ckpts/cp.ckpt
# Epoch 27/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5319 - accuracy: 0.3555 - val_loss: 1.5497 - val_accuracy: 0.3180
#
# Epoch 00027: saving model to ckpts/cp.ckpt
# Epoch 28/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.5369 - accuracy: 0.3596 - val_loss: 1.5452 - val_accuracy: 0.3169
#
# Epoch 00028: saving model to ckpts/cp.ckpt
# Epoch 29/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5260 - accuracy: 0.3567 - val_loss: 1.5457 - val_accuracy: 0.3191
#
# Epoch 00029: saving model to ckpts/cp.ckpt
# Epoch 30/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5476 - accuracy: 0.3429 - val_loss: 1.5465 - val_accuracy: 0.3169
#
# Epoch 00030: saving model to ckpts/cp.ckpt
# Epoch 31/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5240 - accuracy: 0.3541 - val_loss: 1.5427 - val_accuracy: 0.3315
#
# Epoch 00031: saving model to ckpts/cp.ckpt
# Epoch 32/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5342 - accuracy: 0.3612 - val_loss: 1.5418 - val_accuracy: 0.3337
#
# Epoch 00032: saving model to ckpts/cp.ckpt
# Epoch 33/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5247 - accuracy: 0.3369 - val_loss: 1.5397 - val_accuracy: 0.3337
#
# Epoch 00033: saving model to ckpts/cp.ckpt
# Epoch 34/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5240 - accuracy: 0.3610 - val_loss: 1.5472 - val_accuracy: 0.3315
#
# Epoch 00034: saving model to ckpts/cp.ckpt
# Epoch 35/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.5174 - accuracy: 0.3581 - val_loss: 1.5382 - val_accuracy: 0.3382
#
# Epoch 00035: saving model to ckpts/cp.ckpt
# Epoch 36/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5208 - accuracy: 0.3570 - val_loss: 1.5412 - val_accuracy: 0.3348
#
# Epoch 00036: saving model to ckpts/cp.ckpt
# Epoch 37/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.5346 - accuracy: 0.3510 - val_loss: 1.5402 - val_accuracy: 0.3382
#
# Epoch 00037: saving model to ckpts/cp.ckpt
# Epoch 38/150
# 159/159 [==============================] - 12s 77ms/step - loss: 1.5169 - accuracy: 0.3470 - val_loss: 1.5366 - val_accuracy: 0.3348
#
# Epoch 00038: saving model to ckpts/cp.ckpt
# Epoch 39/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.5273 - accuracy: 0.3594 - val_loss: 1.5369 - val_accuracy: 0.3359
#
# Epoch 00039: saving model to ckpts/cp.ckpt
# Epoch 40/150
# 159/159 [==============================] - 13s 81ms/step - loss: 1.5134 - accuracy: 0.3639 - val_loss: 1.5384 - val_accuracy: 0.3359
#
# Epoch 00040: saving model to ckpts/cp.ckpt
# Epoch 41/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5117 - accuracy: 0.3649 - val_loss: 1.5360 - val_accuracy: 0.3371
#
# Epoch 00041: saving model to ckpts/cp.ckpt
# Epoch 42/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5193 - accuracy: 0.3525 - val_loss: 1.5346 - val_accuracy: 0.3359
#
# Epoch 00042: saving model to ckpts/cp.ckpt
# Epoch 43/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5250 - accuracy: 0.3547 - val_loss: 1.5358 - val_accuracy: 0.3415
#
# Epoch 00043: saving model to ckpts/cp.ckpt
# Epoch 44/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.5328 - accuracy: 0.3409 - val_loss: 1.5344 - val_accuracy: 0.3371
#
# Epoch 00044: saving model to ckpts/cp.ckpt
# Epoch 45/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5186 - accuracy: 0.3491 - val_loss: 1.5329 - val_accuracy: 0.3303
#
# Epoch 00045: saving model to ckpts/cp.ckpt
# Epoch 46/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5170 - accuracy: 0.3552 - val_loss: 1.5356 - val_accuracy: 0.3382
#
# Epoch 00046: saving model to ckpts/cp.ckpt
# Epoch 47/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5197 - accuracy: 0.3596 - val_loss: 1.5326 - val_accuracy: 0.3337
#
# Epoch 00047: saving model to ckpts/cp.ckpt
# Epoch 48/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5219 - accuracy: 0.3512 - val_loss: 1.5285 - val_accuracy: 0.3382
#
# Epoch 00048: saving model to ckpts/cp.ckpt
# Epoch 49/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5220 - accuracy: 0.3607 - val_loss: 1.5319 - val_accuracy: 0.3371
#
# Epoch 00049: saving model to ckpts/cp.ckpt
# Epoch 50/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5082 - accuracy: 0.3673 - val_loss: 1.5302 - val_accuracy: 0.3371
#
# Epoch 00050: saving model to ckpts/cp.ckpt
# Epoch 51/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5293 - accuracy: 0.3521 - val_loss: 1.5289 - val_accuracy: 0.3371
#
# Epoch 00051: saving model to ckpts/cp.ckpt
# Epoch 52/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5254 - accuracy: 0.3535 - val_loss: 1.5280 - val_accuracy: 0.3359
#
# Epoch 00052: saving model to ckpts/cp.ckpt
# Epoch 53/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5044 - accuracy: 0.3565 - val_loss: 1.5241 - val_accuracy: 0.3348
#
# Epoch 00053: saving model to ckpts/cp.ckpt
# Epoch 54/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5135 - accuracy: 0.3548 - val_loss: 1.5281 - val_accuracy: 0.3359
#
# Epoch 00054: saving model to ckpts/cp.ckpt
# Epoch 55/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.5151 - accuracy: 0.3523 - val_loss: 1.5234 - val_accuracy: 0.3348
#
# Epoch 00055: saving model to ckpts/cp.ckpt
# Epoch 56/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5191 - accuracy: 0.3508 - val_loss: 1.5255 - val_accuracy: 0.3393
#
# Epoch 00056: saving model to ckpts/cp.ckpt
# Epoch 57/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5206 - accuracy: 0.3606 - val_loss: 1.5297 - val_accuracy: 0.3404
#
# Epoch 00057: saving model to ckpts/cp.ckpt
# Epoch 58/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4983 - accuracy: 0.3654 - val_loss: 1.5274 - val_accuracy: 0.3393
#
# Epoch 00058: saving model to ckpts/cp.ckpt
# Epoch 59/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.5234 - accuracy: 0.3564 - val_loss: 1.5238 - val_accuracy: 0.3415
#
# Epoch 00059: saving model to ckpts/cp.ckpt
# Epoch 60/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4985 - accuracy: 0.3730 - val_loss: 1.5275 - val_accuracy: 0.3427
#
# Epoch 00060: saving model to ckpts/cp.ckpt
# Epoch 61/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5185 - accuracy: 0.3551 - val_loss: 1.5262 - val_accuracy: 0.3393
#
# Epoch 00061: saving model to ckpts/cp.ckpt
# Epoch 62/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4940 - accuracy: 0.3678 - val_loss: 1.5234 - val_accuracy: 0.3438
#
# Epoch 00062: saving model to ckpts/cp.ckpt
# Epoch 63/150
# 159/159 [==============================] - 13s 82ms/step - loss: 1.5055 - accuracy: 0.3582 - val_loss: 1.5240 - val_accuracy: 0.3382
#
# Epoch 00063: saving model to ckpts/cp.ckpt
# Epoch 64/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.5085 - accuracy: 0.3688 - val_loss: 1.5228 - val_accuracy: 0.3393
#
# Epoch 00064: saving model to ckpts/cp.ckpt
# Epoch 65/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4896 - accuracy: 0.3740 - val_loss: 1.5201 - val_accuracy: 0.3460
#
# Epoch 00065: saving model to ckpts/cp.ckpt
# Epoch 66/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5104 - accuracy: 0.3570 - val_loss: 1.5241 - val_accuracy: 0.3438
#
# Epoch 00066: saving model to ckpts/cp.ckpt
# Epoch 67/150
# 159/159 [==============================] - 13s 79ms/step - loss: 1.5077 - accuracy: 0.3576 - val_loss: 1.5196 - val_accuracy: 0.3427
#
# Epoch 00067: saving model to ckpts/cp.ckpt
# Epoch 68/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.4991 - accuracy: 0.3693 - val_loss: 1.5204 - val_accuracy: 0.3371
#
# Epoch 00068: saving model to ckpts/cp.ckpt
# Epoch 69/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4949 - accuracy: 0.3571 - val_loss: 1.5208 - val_accuracy: 0.3449
#
# Epoch 00069: saving model to ckpts/cp.ckpt
# Epoch 70/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4850 - accuracy: 0.3716 - val_loss: 1.5210 - val_accuracy: 0.3393
#
# Epoch 00070: saving model to ckpts/cp.ckpt
# Epoch 71/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.5012 - accuracy: 0.3590 - val_loss: 1.5219 - val_accuracy: 0.3427
#
# Epoch 00071: saving model to ckpts/cp.ckpt
# Epoch 72/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4936 - accuracy: 0.3676 - val_loss: 1.5215 - val_accuracy: 0.3415
#
# Epoch 00072: saving model to ckpts/cp.ckpt
# Epoch 73/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4956 - accuracy: 0.3685 - val_loss: 1.5198 - val_accuracy: 0.3483
#
# Epoch 00073: saving model to ckpts/cp.ckpt
# Epoch 74/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5026 - accuracy: 0.3593 - val_loss: 1.5159 - val_accuracy: 0.3483
#
# Epoch 00074: saving model to ckpts/cp.ckpt
# Epoch 75/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4955 - accuracy: 0.3730 - val_loss: 1.5167 - val_accuracy: 0.3427
#
# Epoch 00075: saving model to ckpts/cp.ckpt
# Epoch 76/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.5198 - accuracy: 0.3592 - val_loss: 1.5201 - val_accuracy: 0.3471
#
# Epoch 00076: saving model to ckpts/cp.ckpt
# Epoch 77/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4846 - accuracy: 0.3790 - val_loss: 1.5180 - val_accuracy: 0.3471
#
# Epoch 00077: saving model to ckpts/cp.ckpt
# Epoch 78/150
# 159/159 [==============================] - 12s 76ms/step - loss: 1.4938 - accuracy: 0.3730 - val_loss: 1.5216 - val_accuracy: 0.3404
#
# Epoch 00078: saving model to ckpts/cp.ckpt
# Epoch 79/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4926 - accuracy: 0.3613 - val_loss: 1.5191 - val_accuracy: 0.3438
#
# Epoch 00079: saving model to ckpts/cp.ckpt
# Epoch 80/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.5075 - accuracy: 0.3576 - val_loss: 1.5126 - val_accuracy: 0.3471
#
# Epoch 00080: saving model to ckpts/cp.ckpt
# Epoch 81/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4953 - accuracy: 0.3780 - val_loss: 1.5154 - val_accuracy: 0.3427
#
# Epoch 00081: saving model to ckpts/cp.ckpt
# Epoch 82/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4926 - accuracy: 0.3604 - val_loss: 1.5146 - val_accuracy: 0.3483
#
# Epoch 00082: saving model to ckpts/cp.ckpt
# Epoch 83/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4900 - accuracy: 0.3612 - val_loss: 1.5136 - val_accuracy: 0.3471
#
# Epoch 00083: saving model to ckpts/cp.ckpt
# Epoch 84/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4988 - accuracy: 0.3624 - val_loss: 1.5117 - val_accuracy: 0.3505
#
# Epoch 00084: saving model to ckpts/cp.ckpt
# Epoch 85/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4798 - accuracy: 0.3634 - val_loss: 1.5125 - val_accuracy: 0.3460
#
# Epoch 00085: saving model to ckpts/cp.ckpt
# Epoch 86/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4812 - accuracy: 0.3786 - val_loss: 1.5128 - val_accuracy: 0.3460
#
# Epoch 00086: saving model to ckpts/cp.ckpt
# Epoch 87/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4877 - accuracy: 0.3763 - val_loss: 1.5118 - val_accuracy: 0.3483
#
# Epoch 00087: saving model to ckpts/cp.ckpt
# Epoch 88/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4827 - accuracy: 0.3729 - val_loss: 1.5128 - val_accuracy: 0.3494
#
# Epoch 00088: saving model to ckpts/cp.ckpt
# Epoch 89/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4801 - accuracy: 0.3745 - val_loss: 1.5113 - val_accuracy: 0.3483
#
# Epoch 00089: saving model to ckpts/cp.ckpt
# Epoch 90/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4828 - accuracy: 0.3719 - val_loss: 1.5099 - val_accuracy: 0.3516
#
# Epoch 00090: saving model to ckpts/cp.ckpt
# Epoch 91/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4965 - accuracy: 0.3633 - val_loss: 1.5119 - val_accuracy: 0.3539
#
# Epoch 00091: saving model to ckpts/cp.ckpt
# Epoch 92/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4869 - accuracy: 0.3747 - val_loss: 1.5110 - val_accuracy: 0.3539
#
# Epoch 00092: saving model to ckpts/cp.ckpt
# Epoch 93/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4880 - accuracy: 0.3659 - val_loss: 1.5080 - val_accuracy: 0.3561
#
# Epoch 00093: saving model to ckpts/cp.ckpt
# Epoch 94/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4775 - accuracy: 0.3789 - val_loss: 1.5106 - val_accuracy: 0.3527
#
# Epoch 00094: saving model to ckpts/cp.ckpt
# Epoch 95/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4806 - accuracy: 0.3671 - val_loss: 1.5089 - val_accuracy: 0.3583
#
# Epoch 00095: saving model to ckpts/cp.ckpt
# Epoch 96/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4811 - accuracy: 0.3677 - val_loss: 1.5064 - val_accuracy: 0.3583
#
# Epoch 00096: saving model to ckpts/cp.ckpt
# Epoch 97/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4901 - accuracy: 0.3630 - val_loss: 1.5074 - val_accuracy: 0.3550
#
# Epoch 00097: saving model to ckpts/cp.ckpt
# Epoch 98/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4918 - accuracy: 0.3720 - val_loss: 1.5068 - val_accuracy: 0.3539
#
# Epoch 00098: saving model to ckpts/cp.ckpt
# Epoch 99/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4846 - accuracy: 0.3684 - val_loss: 1.5084 - val_accuracy: 0.3606
#
# Epoch 00099: saving model to ckpts/cp.ckpt
# Epoch 100/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4786 - accuracy: 0.3788 - val_loss: 1.5056 - val_accuracy: 0.3572
#
# Epoch 00100: saving model to ckpts/cp.ckpt
# Epoch 101/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4984 - accuracy: 0.3720 - val_loss: 1.5073 - val_accuracy: 0.3550
#
# Epoch 00101: saving model to ckpts/cp.ckpt
# Epoch 102/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4830 - accuracy: 0.3642 - val_loss: 1.5043 - val_accuracy: 0.3561
#
# Epoch 00102: saving model to ckpts/cp.ckpt
# Epoch 103/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4756 - accuracy: 0.3669 - val_loss: 1.5040 - val_accuracy: 0.3572
#
# Epoch 00103: saving model to ckpts/cp.ckpt
# Epoch 104/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4790 - accuracy: 0.3872 - val_loss: 1.5035 - val_accuracy: 0.3572
#
# Epoch 00104: saving model to ckpts/cp.ckpt
# Epoch 105/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4878 - accuracy: 0.3647 - val_loss: 1.5052 - val_accuracy: 0.3550
#
# Epoch 00105: saving model to ckpts/cp.ckpt
# Epoch 106/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4680 - accuracy: 0.3803 - val_loss: 1.5039 - val_accuracy: 0.3561
#
# Epoch 00106: saving model to ckpts/cp.ckpt
# Epoch 107/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4876 - accuracy: 0.3720 - val_loss: 1.5033 - val_accuracy: 0.3583
#
# Epoch 00107: saving model to ckpts/cp.ckpt
# Epoch 108/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4805 - accuracy: 0.3780 - val_loss: 1.5021 - val_accuracy: 0.3505
#
# Epoch 00108: saving model to ckpts/cp.ckpt
# Epoch 109/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4804 - accuracy: 0.3767 - val_loss: 1.5025 - val_accuracy: 0.3595
#
# Epoch 00109: saving model to ckpts/cp.ckpt
# Epoch 110/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4921 - accuracy: 0.3653 - val_loss: 1.5042 - val_accuracy: 0.3561
#
# Epoch 00110: saving model to ckpts/cp.ckpt
# Epoch 111/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4818 - accuracy: 0.3668 - val_loss: 1.4998 - val_accuracy: 0.3583
#
# Epoch 00111: saving model to ckpts/cp.ckpt
# Epoch 112/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4824 - accuracy: 0.3689 - val_loss: 1.5036 - val_accuracy: 0.3539
#
# Epoch 00112: saving model to ckpts/cp.ckpt
# Epoch 113/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4783 - accuracy: 0.3701 - val_loss: 1.5005 - val_accuracy: 0.3583
#
# Epoch 00113: saving model to ckpts/cp.ckpt
# Epoch 114/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4776 - accuracy: 0.3776 - val_loss: 1.4983 - val_accuracy: 0.3572
#
# Epoch 00114: saving model to ckpts/cp.ckpt
# Epoch 115/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4752 - accuracy: 0.3718 - val_loss: 1.5003 - val_accuracy: 0.3583
#
# Epoch 00115: saving model to ckpts/cp.ckpt
# Epoch 116/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4747 - accuracy: 0.3802 - val_loss: 1.5004 - val_accuracy: 0.3505
#
# Epoch 00116: saving model to ckpts/cp.ckpt
# Epoch 117/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4844 - accuracy: 0.3721 - val_loss: 1.4979 - val_accuracy: 0.3583
#
# Epoch 00117: saving model to ckpts/cp.ckpt
# Epoch 118/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4678 - accuracy: 0.3813 - val_loss: 1.5008 - val_accuracy: 0.3583
#
# Epoch 00118: saving model to ckpts/cp.ckpt
# Epoch 119/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4744 - accuracy: 0.3692 - val_loss: 1.4994 - val_accuracy: 0.3595
#
# Epoch 00119: saving model to ckpts/cp.ckpt
# Epoch 120/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4726 - accuracy: 0.3807 - val_loss: 1.4993 - val_accuracy: 0.3583
#
# Epoch 00120: saving model to ckpts/cp.ckpt
# Epoch 121/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4741 - accuracy: 0.3728 - val_loss: 1.4976 - val_accuracy: 0.3572
#
# Epoch 00121: saving model to ckpts/cp.ckpt
# Epoch 122/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4880 - accuracy: 0.3584 - val_loss: 1.4954 - val_accuracy: 0.3550
#
# Epoch 00122: saving model to ckpts/cp.ckpt
# Epoch 123/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4683 - accuracy: 0.3825 - val_loss: 1.4966 - val_accuracy: 0.3550
#
# Epoch 00123: saving model to ckpts/cp.ckpt
# Epoch 124/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4671 - accuracy: 0.3857 - val_loss: 1.4946 - val_accuracy: 0.3572
#
# Epoch 00124: saving model to ckpts/cp.ckpt
# Epoch 125/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4787 - accuracy: 0.3710 - val_loss: 1.4962 - val_accuracy: 0.3572
#
# Epoch 00125: saving model to ckpts/cp.ckpt
# Epoch 126/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4792 - accuracy: 0.3731 - val_loss: 1.4949 - val_accuracy: 0.3561
#
# Epoch 00126: saving model to ckpts/cp.ckpt
# Epoch 127/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4727 - accuracy: 0.3746 - val_loss: 1.4938 - val_accuracy: 0.3505
#
# Epoch 00127: saving model to ckpts/cp.ckpt
# Epoch 128/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4713 - accuracy: 0.3795 - val_loss: 1.4943 - val_accuracy: 0.3539
#
# Epoch 00128: saving model to ckpts/cp.ckpt
# Epoch 129/150
# 159/159 [==============================] - 11s 72ms/step - loss: 1.4709 - accuracy: 0.3712 - val_loss: 1.4925 - val_accuracy: 0.3572
#
# Epoch 00129: saving model to ckpts/cp.ckpt
# Epoch 130/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4703 - accuracy: 0.3729 - val_loss: 1.4937 - val_accuracy: 0.3595
#
# Epoch 00130: saving model to ckpts/cp.ckpt
# Epoch 131/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4652 - accuracy: 0.3761 - val_loss: 1.4908 - val_accuracy: 0.3606
#
# Epoch 00131: saving model to ckpts/cp.ckpt
# Epoch 132/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4618 - accuracy: 0.3779 - val_loss: 1.4924 - val_accuracy: 0.3550
#
# Epoch 00132: saving model to ckpts/cp.ckpt
# Epoch 133/150
# 159/159 [==============================] - 11s 70ms/step - loss: 1.4682 - accuracy: 0.3744 - val_loss: 1.4914 - val_accuracy: 0.3595
#
# Epoch 00133: saving model to ckpts/cp.ckpt
# Epoch 134/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4568 - accuracy: 0.3897 - val_loss: 1.4925 - val_accuracy: 0.3550
#
# Epoch 00134: saving model to ckpts/cp.ckpt
# Epoch 135/150
# 159/159 [==============================] - 11s 68ms/step - loss: 1.4711 - accuracy: 0.3814 - val_loss: 1.4926 - val_accuracy: 0.3561
#
# Epoch 00135: saving model to ckpts/cp.ckpt
# Epoch 136/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4745 - accuracy: 0.3720 - val_loss: 1.4942 - val_accuracy: 0.3561
#
# Epoch 00136: saving model to ckpts/cp.ckpt
# Epoch 137/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4544 - accuracy: 0.3990 - val_loss: 1.4930 - val_accuracy: 0.3617
#
# Epoch 00137: saving model to ckpts/cp.ckpt
# Epoch 138/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4692 - accuracy: 0.3710 - val_loss: 1.4956 - val_accuracy: 0.3550
#
# Epoch 00138: saving model to ckpts/cp.ckpt
# Epoch 139/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4658 - accuracy: 0.3744 - val_loss: 1.4918 - val_accuracy: 0.3561
#
# Epoch 00139: saving model to ckpts/cp.ckpt
# Epoch 140/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4458 - accuracy: 0.3892 - val_loss: 1.4900 - val_accuracy: 0.3561
#
# Epoch 00140: saving model to ckpts/cp.ckpt
# Epoch 141/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4858 - accuracy: 0.3752 - val_loss: 1.4931 - val_accuracy: 0.3561
#
# Epoch 00141: saving model to ckpts/cp.ckpt
# Epoch 142/150
# 159/159 [==============================] - 11s 69ms/step - loss: 1.4713 - accuracy: 0.3745 - val_loss: 1.4876 - val_accuracy: 0.3561
#
# Epoch 00142: saving model to ckpts/cp.ckpt
# Epoch 143/150
# 159/159 [==============================] - 12s 74ms/step - loss: 1.4480 - accuracy: 0.3987 - val_loss: 1.4907 - val_accuracy: 0.3561
#
# Epoch 00143: saving model to ckpts/cp.ckpt
# Epoch 144/150
# 159/159 [==============================] - 12s 75ms/step - loss: 1.4643 - accuracy: 0.3695 - val_loss: 1.4878 - val_accuracy: 0.3527
#
# Epoch 00144: saving model to ckpts/cp.ckpt
# Epoch 145/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4614 - accuracy: 0.3796 - val_loss: 1.4902 - val_accuracy: 0.3561
#
# Epoch 00145: saving model to ckpts/cp.ckpt
# Epoch 146/150
# 159/159 [==============================] - 12s 73ms/step - loss: 1.4611 - accuracy: 0.3795 - val_loss: 1.4897 - val_accuracy: 0.3550
#
# Epoch 00146: saving model to ckpts/cp.ckpt
# Epoch 147/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4660 - accuracy: 0.3765 - val_loss: 1.4887 - val_accuracy: 0.3595
#
# Epoch 00147: saving model to ckpts/cp.ckpt
# Epoch 148/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4499 - accuracy: 0.3904 - val_loss: 1.4887 - val_accuracy: 0.3606
#
# Epoch 00148: saving model to ckpts/cp.ckpt
# Epoch 149/150
# 159/159 [==============================] - 12s 72ms/step - loss: 1.4592 - accuracy: 0.3842 - val_loss: 1.4873 - val_accuracy: 0.3583
#
# Epoch 00149: saving model to ckpts/cp.ckpt
# Epoch 150/150
# 159/159 [==============================] - 11s 71ms/step - loss: 1.4406 - accuracy: 0.3880 - val_loss: 1.4889 - val_accuracy: 0.3606
#
# Epoch 00150: saving model to ckpts/cp.ckpt

# %% [markdown]
# ## Metrics

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
accuracy = model.evaluate(X_test, y_test)
print('Loss: {:0.3f}\nAccuracy: {:0.3f}'.format(accuracy[0],accuracy[1]))
# Out:
# 47/47 [==============================] - 1s 12ms/step - loss: 1.4151 - accuracy: 0.4352
# Loss: 1.415
# Accuracy: 0.435

# %%
prediction = model.predict_classes(X_test)
label = np.where(y_test)[1]

# %%
confusion = confusion_matrix(labels=label, predictions=prediction, num_classes=6)

# %%
cate = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad']

# %%
cm = pd.DataFrame(confusion.numpy(), index = [i for i in cate] , columns = [i for i in cate])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
